# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv("../datasets/decisiontree_classification.csv")

df["Result"] = df["Result"].map({
    "Fail" : 0, 
    "Good" : 1, 
    "Average" : 2, 
    "Excellent" : 3
})

X = df[["StudyHours"]]
y = df["Result"]

model = DecisionTreeClassifier(
    criterion="entropy",
    random_state=42
)

#model train 
model.fit(X,y)
print(model.tree_.threshold)
new_students = pd.DataFrame({
    "StudyHours" : [2,3,5]
})
predictions = model.predict(new_students)
print(predictions)
# Out:
# [ 4.75  2.75 -2.   -2.    6.5  -2.   -2.  ]
# [0 1 2]

# %%
df = pd.read_csv("../datasets/student_multiclass_multiple_features.csv")
df["Result"] = df["Result"].map({
    "Fail" : 0, 
    "Average" : 1, 
    "Good" : 2
})

X = df[["StudyHours","Attendance","PreviousMarks"]]
y = df["Result"]

model = DecisionTreeClassifier(
    criterion="entropy",
    random_state=42
)
#model train 
model.fit(X,y)
# print(model.tree_.threshold)
new_students = pd.DataFrame({
    "StudyHours" : [5], 
    "Attendance" : [70],
    "PreviousMarks" : [65]
    
})
predictions = model.predict(new_students)
print(predictions)
# Out:
# [1]

# %%
df = pd.read_csv("../datasets/student_multilabel.csv")
X = df[["StudyHours","EnglishScore","MathScore"]]
y = df[["PassEnglish","PassMath"]]
model = DecisionTreeClassifier(
    criterion="gini",
    random_state=42
)
model.fit(X,y)
new_student = pd.DataFrame({
    "StudyHours" : [15],
    "EnglishScore" : [60], 
    "MathScore":[85]
})
model.predict(new_student)
# Out:
# array([[1, 1]])
