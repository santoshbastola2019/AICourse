# %%
import pandas as pd
result = pd.Series(["japan","usa","nepal"])
print(result)
# Out:
# 0    japan
# 1      usa
# 2    nepal
# dtype: str

# %%
numbers_series = pd.Series([10, 20, 30], index = ["ek","dui","tin"])
print(numbers_series["tin"])
print(numbers_series["dui"])
# Out:
# 30
# 20

# %%
student_data = {
    "name" : ["Manish", "Anish", "nish"],
    "age" :[24, 23, 22],
    "course" : ["ai_udaan", "mern", "reactjs"]
}
student_dataframe = pd.DataFrame(student_data)
print(student_dataframe)
# Out:
#      name  age    course
# 0  Manish   24  ai_udaan
# 1   Anish   23      mern
# 2    nish   22   reactjs

# %%
students_data = pd.read_csv("../datasets/student_dataset.csv")
print(students_data)
# Out:
#       study_hours  attendance  sleep_hours  internet_usage  \
# 0               7          56            8               7
# 1               4          69            5               3
# 2              11          60            7               6
# 3               8          99            9               8
# 4               5          52            8               6
# ...           ...         ...          ...             ...
# 9995            2          58            9               7
# 9996            7          98            6               9
# 9997           10          44            8               5
# 9998           10          75            7               5
# 9999            2          70            6              11
#
#       assignments_completed  previous_score  exam_score placement_status
# 0                        10              62      100.00           Placed
# 1                         8              56      100.00           Placed
# ...

# %%
excel_data = pd.read_excel("../datasets/exceldata.xlsx")
print(excel_data.head())
# Out:
#      FY  FY Period Month  Cal Year  Awd/Prop Award Type  \
# 0  2021          7   Jan      2021  Proposal        NaN
# 1  2021          7   Jan      2021  Proposal        NaN
# 2  2021          7   Jan      2021  Proposal        NaN
# 3  2021          7   Jan      2021  Proposal        NaN
# 4  2021          7   Jan      2021  Proposal        NaN
#
#                               College                      Department  \
# 0  College of Business Administration     Hospitality Research Center
# 1              College of Engineering          Mechanical Engineering
# 2      College of LA, Educ, & Hum Dev      Anthropology and Sociology
# 3      College of LA, Educ, & Hum Dev  Entrepreneurship & Policy Inst
# 4      College of LA, Educ, & Hum Dev                       UNO-CHART
#
#                PI Name                              Sponsor Name  \
# 0   Markus R Schuckert  LA Dept of Culture, Recreation & Tourism
# 1     Paul J Schilling                             Alta Max, LLC
# ...

# %%
data_json = pd.read_json("../datasets/todos.json")
print(data_json.head())
# Out:
#    userId  id                                              title  \
# 0       1   1  sunt aut facere repellat provident occaecati e...
# 1       1   2                                       qui est esse
# 2       1   3  ea molestias quasi exercitationem repellat qui...
# 3       1   4                               eum et est occaecati
# 4       1   5                                 nesciunt quas odio
#
#                                                 body
# 0  quia et suscipit\nsuscipit recusandae consequu...
# 1  est rerum tempore vitae\nsequi sint nihil repr...
# 2  et iusto sed quo iure\nvoluptatem occaecati om...
# 3  ullam et saepe reiciendis voluptatem adipisci\...
# 4  repudiandae veniam quaerat sunt sed\nalias aut...

# %%
nd = pd.read_csv("../datasets/netflix_dataset.csv")
# print(nd.head()) # returns top 5 rows
# print(nd.tail()) # returns last 5 rows
# print(sample(3)) # returns random row data
# print(nd.shape)
# print(nd.columns)
print(nd.dtypes)
# print(nd.info()) # shape, columns, dtypes all info
# print(nd.describe()) # numerical description or statistical info
# Out:
# show_id           str
# type              str
# title             str
# director          str
# cast              str
# country           str
# date_added        str
# release_year    int64
# rating            str
# duration          str
# listed_in         str
# description       str
# dtype: object
