# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df1 = pd.DataFrame({
    "Employee_Name" : ["Ramesh", "Amesh", "Mesh", "Esh", "Sh", "H", "Anish", "Nish"],
    "Salary" : [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000]
})
df1
# Out:
#   Employee_Name  Salary
# 0        Ramesh    1000
# 1         Amesh    2000
# 2          Mesh    3000
# 3           Esh    4000
# 4            Sh    5000
# 5             H    6000
# 6         Anish    7000
# 7          Nish    8000

# %%
plt.boxplot(df1["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x274aa73c1a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x274aa73c440>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x274aa73c050>],
#  'medians': [<matplotlib.lines.Line2D at 0x274aa73c6e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x274aa73c830>],
#  'means': []}

# %%
df2 = pd.DataFrame({
    "Employee_Name" : ["Ramesh", "Amesh", "Mesh", "Esh", "Sh", "H", "Anish", "Nish", "OutlierName"],
    "Salary" : [1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 50000]
})
df2
# Out:
#   Employee_Name  Salary
# 0        Ramesh    1000
# 1         Amesh    2000
# 2          Mesh    3000
# 3           Esh    4000
# 4            Sh    5000
# 5             H    6000
# 6         Anish    7000
# 7          Nish    8000
# 8   OutlierName   50000

# %%
plt.boxplot(df2["Salary"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x274aa560050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x274aa5602f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x274aa73fe00>],
#  'medians': [<matplotlib.lines.Line2D at 0x274aa560590>],
#  'fliers': [<matplotlib.lines.Line2D at 0x274aa5606e0>],
#  'means': []}

# %%
df3 = pd.read_csv("../datasets/daraz_dataset.csv")
plt.boxplot(df3["TotalAmount"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x274aa563380>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x274aa563620>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x274aa563230>],
#  'medians': [<matplotlib.lines.Line2D at 0x274aa5638c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x274aa563a10>],
#  'means': []}

# %%
plt.boxplot(df3["UnitPrice"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x274ab0b6510>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x274ab0b67b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x274ab0b63c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x274ab0b6a50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x274ab0b6ba0>],
#  'means': []}
