# %%
import pandas as pd
# df = pd.read_csv("../datasets/daraz_dataset.csv")

# print(df.shape)
print(df.columns)
# print(df.info())
# print(df["TotalAmount"].max())
# print(df["TotalAmount"].min())
# print(df["TotalAmount"].mean())   
# print(df[["CustomerName", "District", "TotalAmount"]])
# print(df.iloc[11]) # 11th number index of row lae retrive garyo
# print(df.iloc[0:5])
# print(df.iloc[0, 2]) # to catch a specific cell
# print(df.iloc[:, [2, 6, 8]]) # to retrieve particular column or multiple columns
# print(df.iloc[-1])

# print(df.loc[:, ["CustomerName", "District"]])
# print(df[df["District"] == "Kathmandu"]) 
# print(df.loc[df["District"] == "Kathmandu"])
# print(df.loc[df["TotalAmount"] > 30000])

# Filter chaining --> kathmandu district bata esewa payment method used
# print(df[(df["District"] == "Kathmandu") & (df["PaymentMethod"] == "eSewa")])
# print(df[(df["Category"] == "Electronics") & (df["Rating"] == 5)])
# print(df.sort_values("TotalAmount", ascending = False))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 5
#       1 import pandas as pd
#       2 # df = pd.read_csv("../datasets/daraz_dataset.csv")
#       3
#       4 # print(df.shape)
# ----> 5 print(df.columns)
#       6 # print(df.info())
#       7 # print(df["TotalAmount"].max())
#       8 # print(df["TotalAmount"].min())
#
# NameError: name 'df' is not defined

# %%
# Cleaning the bad data
df = pd.read_csv("../datasets/bad_daraz_dataset.csv")
df
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          10         Haha  Electronics   2500                5     4.4
# ...

# %%
# df.isnull().sum() # NaN missing values datatypes catch and sum
# df.fillna(0) # Add 0 to NaN values
df["price"] = pd.to_numeric(df["price"], errors = "coerce")
df["price"] = df["price"].fillna(df["price"].mean())
df
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
df["age"] = pd.to_numeric(df["age"], errors = "coerce")
df["age"] = df["age"].fillna(df["age"].median())
df
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
# df.dropna()
# df[df.duplicated()]

# remove "%" 
df["discount_percent"] = df["discount_percent"].replace("%", "")
df
# Out:
#     product_id product_name     category         price discount_percent  \
# 0            1       Laptop  Electronics  75000.000000               10
# 1            2        Phone  Electronics  14981.818182               15
# 2            3        Shoes      Fashion   3500.000000               5%
# 3            4      T-Shirt      Fashion   1500.000000               20
# 4            5        Watch  Accessories   5500.000000               10
# 5            6   Headphones  Electronics   4200.000000              NaN
# 6            7       Laptop  Electronics  75000.000000               10
# 7            8          Bag      Fashion  14981.818182               12
# 8            9        Mouse  Electronics   1800.000000                5
# 9           10     Keyboard  Electronics   2500.000000                5
# 10          11       Bottle         Home    800.000000                0
# 11          12        Chair    Furniture  -2500.000000               10
# ...

# %%
# Cleaning a dublicate data
# df.duplicated().sum() # returns the count of duplicates in the dataset
df[df.duplicated()]
# Out:
#     product_id product_name   category  price discount_percent  rating stock  \
# 12          12        Chair  Furniture  -2500               10     4.0    -5
#
#      seller      city brand gender_target      age  reviews
# 12  FurniCo  Lalitpur  IKEA        Unisex  Unknown       44

# %%
# Partial Duplicacy (in a particular column
df.duplicated("product_id").sum()
# Out:
# np.int64(2)

# %%
# removes row with complete duplication
df.drop_duplicates(inplace=True)
df
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          11       Bottle         Home    800                0     5.5
# ...

# %%
# partial duplicay
df.drop_duplicates(subset="product_id", inplace = True)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # partial duplicay
# ----> 2 df.drop_duplicates(subset="product_id", inplace = True)
#       3 df["city"].unique()
#
# NameError: name 'df' is not defined

# %%
# Finding the neagtive values
# df["price"] = pd.to_numeric(df["price"], errors = "coerce")
# df[df["price"] < 0]
# Out:
#     product_id product_name   category   price discount_percent  rating stock  \
# 13          12        Chair  Furniture -2500.0               10     4.0    -5
#
#      seller      city brand gender_target      age  reviews
# 13  FurniCo  Lalitpur  IKEA        Unisex  Unknown       44

# %%
# finding abnormal rating that is 5
# df["rating"] = pd.to_numeric(df["rating"], errors = "coerce")
# df[df["rating"] > 5]

# making the neagtive price to 0
# df.loc[df["price"] < 0, "price"] = 0
# df

df = df[df["price"] > 0 ]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 9
#       5 # making the neagtive price to 0
#       6 # df.loc[df["price"] < 0, "price"] = 0
#       7 # df
#       8
# ----> 9 df = df[df["price"] > 0 ]
#
# NameError: name 'df' is not defined

# %%
print(df)
# df["city"] = df["city"].str.lstrip() # removes space from left side 
# df["city"] = df["city"].str.rstrip() # removes space from right side
# df
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          10         Haha  Electronics   2500                5     4.4
# ...

# %%
# df["city"] = df["city"].str.lower()
# df["city"] = df["city"].str.upper()
df["city"] = df["city"].str.title() # only fist letter capital or upper
df
# Out:
#     product_id product_name     category  price discount_percent  rating  \
# 0            1       Laptop  Electronics  75000               10     4.8
# 1            2        Phone  Electronics    NaN               15     4.6
# 2            3        Shoes      Fashion   3500               5%     4.2
# 3            4      T-Shirt      Fashion   1500               20     NaN
# 4            5        Watch  Accessories   5500               10     4.5
# 5            6   Headphones  Electronics   4200              NaN     4.1
# 6            7       Laptop  Electronics  75000               10     4.8
# 7            8          Bag      Fashion    abc               12     3.9
# 8            9        Mouse  Electronics   1800                5     4.3
# 9            9          Cup  Electronics   1800                5     4.3
# 10          10     Keyboard  Electronics   2500                5     4.4
# 11          10         Haha  Electronics   2500                5     4.4
# ...

# %%
# Example of Outlier Detection (IQR method)
df = pd.DataFrame({
    "salary" : [1000, 2000, 3000, 5000, 7000, 8000, 9000, 12000, 50000]
})

# quartiles
median = df["salary"].quantile(0.5)
first_quartile = df["salary"].quantile(0.25)
third_quartile = df["salary"].quantile(0.75)

# IQR 
iqr = third_quartile - first_quartile
lower_bound = first_quartile - (1.5 * iqr)
upper_bound = third_quartile + (1.5 * iqr)
lower_bound, upper_bound
# Out:
# (np.float64(-6000.0), np.float64(18000.0))

# %%
outliers = df[(df["salary"] < -5500) | (df["salary"] > 16500)]
print(outliers)
# Out:
#    salary
# 8   50000
